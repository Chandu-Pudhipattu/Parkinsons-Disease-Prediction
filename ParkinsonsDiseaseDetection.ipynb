# %%
import pandas as pd
import numpy as np

# %%
# let’s read the data into a DataFrame and get the first 5 records.

df = pd.read_csv('parkinsons.data',delimiter=',')

# %%
df
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
# ...

# %%
## fetch one record

df.iloc[0].values
# Out:
# array(['phon_R01_S01_1', 119.992, 157.302, 74.997, 0.00784, 7e-05, 0.0037,
#        0.00554, 0.01109, 0.04374, 0.426, 0.02182, 0.0313, 0.02971,
#        0.06545, 0.02211, 21.033, 1, 0.414783, 0.815285, -4.813031,
#        0.266482, 2.301442, 0.284654], dtype=object)

# %%
# Adding a null records to show the null values representation in heatmap
null_record = pd.DataFrame([[np.nan,119.992, 157.302, 74.997, 0.00784, 7e-05, 0.0037,
       0.00554, 0.01109, 0.04374, 0.426, 0.02182, 0.0313, 0.02971,
       0.06545, 0.02211, 21.033, 1, 0.414783, 0.815285, -4.813031,
       0.266482, 2.301442, 0.284654]], columns=df.columns)
df = pd.concat([df, null_record], ignore_index=True)

# %%
# check if any missing values

df.isnull().sum()
# Out:
# name                1
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
df.dtypes  # nameis object, will convert that into int in the following steps
# Out:
# name                 object
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
## finding missing values using heatmap

import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull(),cbar=True)   # heatmap provides that it has 0 null values
#print(help(sns.heatmap))
# Out:
# <Axes: >

# %%
# removing null records

df.dropna(inplace=True)

# %%
sns.heatmap(df.isnull(),cbar=True)
# Out:
# <Axes: >

# %% [markdown]
# **Matrix column entries (attributes):**
#
# name - ASCII subject name and recording number
#
# MDVP:Fo(Hz) - Average vocal fundamental frequency
#
# MDVP:Fhi(Hz) - Maximum vocal fundamental frequency
#
# MDVP:Flo(Hz) - Minimum vocal fundamental frequency
#
# MDVP:Jitter(%),MDVP:Jitter(Abs),MDVP:RAP,MDVP:PPQ,Jitter:DDP - Several
# measures of variation in fundamental frequency
#
# MDVP:Shimmer,MDVP:Shimmer(dB),Shimmer:APQ3,Shimmer:APQ5,MDVP:APQ,Shimmer:DDA - Several measures of variation in amplitude
#
# NHR,HNR - Two measures of ratio of noise to tonal components in the voice
#
# status - Health status of the subject (one) - Parkinson's, (zero) - healthy
#
# RPDE,D2 - Two nonlinear dynamical complexity measures
#
# DFA - Signal fractal scaling exponent
#
# spread1,spread2,PPE - Three nonlinear measures of fundamental frequency variation

# %%
# check the categorical variables and numerical variables

categorical_features = df.select_dtypes(include='object').columns
numerical_features = df.select_dtypes(exclude='object').columns
print(f"Categorical features: {categorical_features}")
print(f"Numerical features: {numerical_features}")
# Out:
# Categorical features: Index(['name'], dtype='object')
# Numerical features: Index(['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
# lets seperate features and labels(target variable)
df_features = df.drop(['status'],axis=1)
df_labels = df['status']

# %%
# get the count of each label in "status"
df_labels.value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
# lets plot some plots to derive patterns
# histograms
df_features.hist(figsize=(25,25))
plt.show()

# %% [markdown]
# **Observations**
#
# MDVP:Fo(Hz) (Average vocal fundamental frequency): The histogram for MDVP:Fo(Hz) appears to be somewhat normally distributed, but slightly skewed to the right (positive skew). Individuals with Parkinson's might have lower average vocal fundamental frequencies, as indicated by a potential shift in the distribution towards lower values for the 'status=1' group.
#
# MDVP:Fhi(Hz) (Maximum vocal fundamental frequency): The distribution of MDVP:Fhi(Hz) is also slightly skewed to the right. Similar to MDVP:Fo(Hz), individuals with Parkinson's could potentially exhibit lower maximum vocal fundamental frequencies compared to healthy individuals.
#
# MDVP:Flo(Hz) (Minimum vocal fundamental frequency): The histogram for MDVP:Flo(Hz) displays a right-skewed distribution. Parkinson's patients might have higher minimum vocal fundamental frequencies, potentially due to vocal tremors or other speech impairments.
#
# MDVP:Jitter(%) and Related Measures: These features, representing variations in fundamental frequency, tend to have right-skewed distributions. Higher values in these measures could indicate greater vocal instability, which is often associated with Parkinson's disease.
#
# MDVP:Shimmer and Related Measures: These features capture variations in amplitude. They also exhibit right-skewed distributions. Increased shimmer values might suggest a more irregular or tremulous voice, a characteristic of Parkinson's.
#
# NHR and HNR: These measures represent the ratio of noise to tonal components in the voice. NHR (Noise-to-Harmonics Ratio) often shows a right-skewed distribution, while HNR (Harmonics-to-Noise Ratio) could be more normally distributed. Individuals with Parkinson's may have higher NHR and lower HNR values, indicating a greater presence of noise in their voice.
#
# RPDE, D2, DFA: These features quantify nonlinear dynamical complexity measures. Their distributions might vary, but changes in these measures could be indicative of Parkinson's disease.
#
# Spread1, Spread2, PPE: These nonlinear measures of fundamental frequency variation often exhibit right-skewed distributions. Higher values in these features could suggest greater variability in vocal frequency, a common symptom of Parkinson's.
#
# Reasoning and Considerations
#
# Skewness: Right-skewed distributions are common in many of the features. This indicates that the majority of values are concentrated towards the lower end, with a tail extending towards higher values. These tails often represent individuals with Parkinson's, who might exhibit more extreme values in these features.
#
# Distribution Shifts: Comparing the distributions between healthy and Parkinson's groups (if possible with further analysis) can reveal shifts in the central tendency or spread of the data. These shifts can provide insights into how the features are affected by the disease.
#
# Feature Importance: While the histograms provide an initial understanding of the distributions, further statistical analysis is necessary to determine the significance of each feature in predicting Parkinson's disease. Techniques like feature selection or correlation analysis can help identify the most important features.

# %%
# Converting categorical feature into numerical feature
y = df_features['name'].map(lambda x:x[10:12].lstrip('0'))
df_features['name'] = y
df_features.rename(columns={'name':'subject'},inplace=True)

# %%
df_features
# Out:
#     subject  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0         1      119.992       157.302        74.997         0.00784
# 1         1      122.400       148.650       113.819         0.00968
# 2         1      116.682       131.111       111.555         0.01050
# 3         1      116.676       137.871       111.366         0.00997
# 4         1      116.014       141.781       110.655         0.01284
# ..      ...          ...           ...           ...             ...
# 190      50      174.188       230.978        94.261         0.00459
# 191      50      209.516       253.017        89.488         0.00564
# 192      50      174.688       240.005        74.287         0.01360
# 193      50      198.764       396.961        74.904         0.00740
# 194      50      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# ...

# %%
# correlation heatmap

plt.figure(figsize=(15,15))
sns.heatmap(df_features.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **Observation**
#
#
# **Strong Positive Correlations**
#
# Vocal Fundamental Frequency Relationships:
#
# MDVP:Fo(Hz) (average vocal fundamental frequency) and MDVP:Fhi(Hz) (maximum vocal fundamental frequency) are strongly positively correlated. This is expected as they both measure aspects of the fundamental frequency of the voice.
# These features likely reflect how high or low a person's voice is on average and at its highest point.
# This correlation suggests that individuals with a higher average vocal fundamental frequency also tend to have a higher maximum vocal fundamental frequency.
#
# Jitter and Shimmer Relationships:
#
# There are strong positive correlations within the jitter and shimmer measures (e.g., MDVP:Jitter(%), MDVP:Jitter(Abs), MDVP:RAP, MDVP:PPQ, Jitter:DDP, MDVP:Shimmer, MDVP:Shimmer(dB), etc.).
# These features capture variations in fundamental frequency and amplitude, respectively.
# These correlations indicate that if a person has higher jitter values (more variations in fundamental frequency), they are also likely to have higher shimmer values (more variations in amplitude).
# This could suggest a general instability in voice production for individuals with Parkinson's disease.
#
# Spread and PPE:
#
# Features like spread1, spread2, and PPE (related to nonlinear measures of fundamental frequency variation) also show positive correlations.
# This suggests that these measures capture similar aspects of vocal variability.
#
# **Strong Negative Correlations:**
#
# Noise and Harmonics:
#
# HNR (harmonics-to-noise ratio) has negative correlations with several jitter and shimmer measures.
# This indicates that as the ratio of noise to tonal components in the voice increases (lower HNR), there is also an increase in vocal instability and variations in amplitude (higher jitter and shimmer).
# This relationship makes sense as noise in the voice is often associated with irregularities in vocal production.
# Fundamental Frequency and Noise:
#
# MDVP:Flo(Hz) (minimum vocal fundamental frequency) might have a negative correlation with HNR.
# This could suggest that individuals with lower minimum vocal fundamental frequencies might have more noise in their voice.
#
# **Weak or No Correlations:**
#
# There might be features with weak or no correlations, indicating that they are not strongly related to each other linearly.
#
# **Overall Observations**
#
# The correlation plot reveals relationships between features that reflect the physiological changes associated with Parkinson's disease.
# Vocal fundamental frequency, jitter, shimmer, and noise-related features show strong correlations, suggesting that these aspects of vocal production are interconnected and affected by the disease.
# These correlations can be used to understand how different features interact and might provide insights into the underlying mechanisms of Parkinson's disease.

# %%
# lets scale the data using minmaxscaler

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler((-1,1))
x = scaler.fit_transform(df_features)

# %%
y = df_labels

# %%
# train test split

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
# lets implement Logistic Rrgression model

from sklearn.linear_model import LogisticRegression

logistic = LogisticRegression()
logistic.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
# predictions and performance metrics

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

y_pred = logistic.predict(x_test)
print(accuracy_score(y_test,y_pred)*100)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 86.4406779661017
# [[ 8  7]
#  [ 1 43]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.53      0.67        15
#            1       0.86      0.98      0.91        44
#
#     accuracy                           0.86        59
#    macro avg       0.87      0.76      0.79        59
# weighted avg       0.87      0.86      0.85        59

# %%
# lets improve by implementing xgboost classifier algorithm

from xgboost import XGBClassifier

xgb = XGBClassifier(base_score=0.5,booster='gbtree',colsample_bylevel=1,
             colsample_bynode=1,colsample_bytree=1,gamma=0,learning_rate=0.1,max_delta_step=0,
             max_depth=3,min_child_weight=1,missing=np.nan,n_estimators=100,n_jobs=1,nthread=None,
             objective='binary:logistic',random_state=0,reg_alpha=0,reg_lambda=1,scale_pos_weight=1,
             seed=None,silent=None,subsample=1,verbosity=1)

xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               device=None, early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=0, max_depth=3,
#               max_leaves=None, min_child_weight=1, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=1, nthread=None, num_parallel_tree=None, ...)

# %%
# predictions and performace metrics

y_pred = xgb.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.9830508474576272
# [[14  1]
#  [ 0 44]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.97        15
#            1       0.98      1.00      0.99        44
#
#     accuracy                           0.98        59
#    macro avg       0.99      0.97      0.98        59
# weighted avg       0.98      0.98      0.98        59

# %%
# lets check for data overfitting using cross validation

from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(xgb, x_train, y_train, cv=5)  # 5-fold cross-validation
print(f"Cross-validation scores: {cv_scores}")
print(f"Mean CV score: {cv_scores.mean()}")
# Out:
# Cross-validation scores: [1.         0.92592593 0.88888889 1.         0.92592593]
# Mean CV score: 0.9481481481481481

# %% [markdown]
# Cross-validation scores: [1. 0.92592593 0.88888889 1. 0.92592593] These are the accuracy scores for each of the 5 folds. In your case, the model performs very well across most of the folds, with one fold showing a slightly lower accuracy (0.88888889), but the others being 1.0 or 0.9259, indicating that the model is performing well across the different subsets of the data.
#
# Mean CV score: 0.9481 This is the average performance of the model across all folds. A mean cross-validation score of 94.81% is a good indicator that your model generalizes well to unseen data and doesn't just memorize the training data (overfitting).

# %%
## Hyper parameter Tuning with GridSearchCV

from sklearn.model_selection import GridSearchCV

# Define parameter grid
param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'n_estimators': [100, 200, 300]
}

grid_search = GridSearchCV(estimator=xgb, param_grid=param_grid, cv=5, scoring='accuracy')
grid_search.fit(x_train, y_train)

print(f"Best parameters: {grid_search.best_params_}")
print(f"Best cross-validation score: {grid_search.best_score_}")
# Out:
# Best parameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
# Best cross-validation score: 0.9555555555555555

# %% [markdown]
# the best cross-validation score is 95.56%. This indicates a very good model performance with the chosen hyperparameters, and it suggests that these values provide a better fit than the default settings.Even if we change max depth to 5 it wont change much.
